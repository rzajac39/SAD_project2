# %% [markdown]
# # Statystyki opisowe i charakterystyka zmiennych

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import auc,roc_curve, ConfusionMatrixDisplay, confusion_matrix, RocCurveDisplay, classification_report, accuracy_score
from sklearn.pipeline import Pipeline
import sklearn.metrics as skm

# %%
df = pd.read_csv("../data/smoking.csv")
df.head()
# Out:
#    ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0      F   40         155          60       81.3             1.2
# 1   1      F   40         160          60       81.0             0.8
# 2   2      M   55         170          60       80.0             0.8
# 3   3      M   40         165          70       88.0             1.5
# 4   4      F   40         155          60       86.0             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# 0              1.0            1.0             1.0  ...        12.9
# 1              0.6            1.0             1.0  ...        12.7
# 2              0.8            1.0             1.0  ...        15.8
# 3              1.5            1.0             1.0  ...        14.7
# 4              1.0            1.0             1.0  ...        12.5
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# 0            1.0               0.7  18.0  19.0  27.0     Y              0
# 1            1.0               0.6  22.0  19.0  18.0     Y              0
# 2            1.0               1.0  21.0  16.0  22.0     Y              0
# 3            1.0               1.0  19.0  26.0  18.0     Y              0
# 4            1.0               0.6  16.0  14.0  22.0     Y              0
#
#    tartar  smoking
# 0       Y        0
# 1       Y        0
# 2       N        1
# 3       Y        0
# 4       N        0
#
# [5 rows x 27 columns]

# %%
df.columns = ['ID', 'gender', 'age', 'height(cm)', 'weight(kg)', 'waist(cm)',
       'eyesight(left)', 'eyesight(right)', 'hearing(left)', 'hearing(right)',
       'systolic', 'relaxation', 'fasting_blood_sugar', 'Cholesterol',
       'triglyceride', 'HDL', 'LDL', 'hemoglobin', 'Urine protein',
       'serum_creatinine', 'AST', 'ALT', 'Gtp', 'oral', 'dental_caries',
       'tartar', 'smoking']

# %% [markdown]
# Usunięcie "ID" oraz "oral"

# %%
df.drop(["ID", "oral"], axis=1, inplace=True)

# %% [markdown]
# Statystki opisowe

# %%
df[df.columns].select_dtypes(int).describe()
# Out:
#                 age    height(cm)    weight(kg)  dental_caries       smoking
# count  55692.000000  55692.000000  55692.000000   55692.000000  55692.000000
# mean      44.182917    164.649321     65.864936       0.213334      0.367288
# std       12.071418      9.194597     12.820306       0.409665      0.482070
# min       20.000000    130.000000     30.000000       0.000000      0.000000
# 25%       40.000000    160.000000     55.000000       0.000000      0.000000
# 50%       40.000000    165.000000     65.000000       0.000000      0.000000
# 75%       55.000000    170.000000     75.000000       0.000000      1.000000
# max       85.000000    190.000000    135.000000       1.000000      1.000000

# %%
df[df.columns].select_dtypes(float).describe()
# Out:
#           waist(cm)  eyesight(left)  eyesight(right)  hearing(left)  \
# count  55692.000000    55692.000000     55692.000000   55692.000000
# mean      82.046418        1.012623         1.007443       1.025587
# std        9.274223        0.486873         0.485964       0.157902
# min       51.000000        0.100000         0.100000       1.000000
# 25%       76.000000        0.800000         0.800000       1.000000
# 50%       82.000000        1.000000         1.000000       1.000000
# 75%       88.000000        1.200000         1.200000       1.000000
# max      129.000000        9.900000         9.900000       2.000000
#
#        hearing(right)      systolic    relaxation  fasting_blood_sugar  \
# count    55692.000000  55692.000000  55692.000000         55692.000000
# mean         1.026144    121.494218     76.004830            99.312325
# std          0.159564     13.675989      9.679278            20.795591
# min          1.000000     71.000000     40.000000            46.000000
# 25%          1.000000    112.000000     70.000000            89.000000
# 50%          1.000000    120.000000     76.000000            96.000000
# 75%          1.000000    130.000000     82.000000           104.000000
# max          2.000000    240.000000    146.000000           505.000000
#
#         Cholesterol  triglyceride           HDL           LDL    hemoglobin  \
# count  55692.000000  55692.000000  55692.000000  55692.000000  55692.000000
# mean     196.901422    126.665697     57.290347    114.964501     14.622592
# std       36.297940     71.639817     14.738963     40.926476      1.564498
# min       55.000000      8.000000      4.000000      1.000000      4.900000
# 25%      172.000000     74.000000     47.000000     92.000000     13.600000
# 50%      195.000000    108.000000     55.000000    113.000000     14.800000
# 75%      220.000000    160.000000     66.000000    136.000000     15.800000
# max      445.000000    999.000000    618.000000   1860.000000     21.100000
#
#        Urine protein  serum_creatinine           AST           ALT  \
# count   55692.000000      55692.000000  55692.000000  55692.000000
# mean        1.087212          0.885738     26.182935     27.036037
# std         0.404882          0.221524     19.355460     30.947853
# min         1.000000          0.100000      6.000000      1.000000
# 25%         1.000000          0.800000     19.000000     15.000000
# 50%         1.000000          0.900000     23.000000     21.000000
# 75%         1.000000          1.000000     28.000000     31.000000
# max         6.000000         11.600000   1311.000000   2914.000000
#
#                 Gtp
# count  55692.000000
# mean      39.952201
# std       50.290539
# min        1.000000
# 25%       17.000000
# 50%       25.000000
# 75%       43.000000
# max      999.000000

# %% [markdown]
# Współczynnik zmienności

# %%
means_and_stds = df.select_dtypes([float, int]).apply(['mean','std']).T
means_and_stds['std'] / means_and_stds['mean'] * 100
# Out:
# age                     27.321459
# height(cm)               5.584352
# weight(kg)              19.464538
# waist(cm)               11.303629
# eyesight(left)          48.080409
# eyesight(right)         48.237423
# hearing(left)           15.396211
# hearing(right)          15.549892
# systolic                11.256494
# relaxation              12.735082
# fasting_blood_sugar     20.939588
# Cholesterol             18.434575
# triglyceride            56.558183
# HDL                     25.726782
# LDL                     35.599229
# hemoglobin              10.699187
# Urine protein           37.240435
# serum_creatinine        25.010131
# AST                     73.923951
# ALT                    114.468893
# Gtp                    125.876765
# dental_caries          192.029957
# smoking                131.251302
# dtype: float64

# %% [markdown]
# Korelacje, bez zmiennych gender oraz tartar, ponieważ są one typu object

# %%
df.drop(["gender", "tartar"], axis=1, inplace=True)
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_fc8d5_row0_col0, #T_fc8d5_row1_col1, #T_fc8d5_row2_col2, #T_fc8d5_row3_col3, #T_fc8d5_row4_col4, #T_fc8d5_row5_col5, #T_fc8d5_row6_col6, #T_fc8d5_row7_col7, #T_fc8d5_row8_col8, #T_fc8d5_row9_col9, #T_fc8d5_row10_col10, #T_fc8d5_row11_col11, #T_fc8d5_row12_col12, #T_fc8d5_row13_col13, #T_fc8d5_row14_col14, #T_fc8d5_row15_col15, #T_fc8d5_row16_col16, #T_fc8d5_row17_col17, #T_fc8d5_row18_col18, #T_fc8d5_row19_col19, #T_fc8d5_row20_col20, #T_fc8d5_row21_col21, #T_fc8d5_row22_col22 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_fc8d5_row0_